# %% [markdown]
# # Northwind Data Profiling

# %%
import pandas as pd

# df = pd.read_csv("./Resources/northwind/products.csv")
df = pd.read_csv("./Resources/northwind/suppliers.csv")
df
# Out:
#     SupplierID                             CompanyName  \
# 0            1                          Exotic Liquids
# 1            2              New Orleans Cajun Delights
# 2            3               Grandma Kelly's Homestead
# 3            4                           Tokyo Traders
# 4            5      Cooperativa de Quesos 'Las Cabras'
# 5            6                                Mayumi's
# 6            7                           Pavlova, Ltd.
# 7            8                Specialty Biscuits, Ltd.
# 8            9                        PB Knäckebröd AB
# 9           10               Refrescos Americanas LTDA
# 10          11             Heli Süßwaren GmbH & Co. KG
# 11          12       Plutzer Lebensmittelgroßmärkte AG
# 12          13  Nord-Ost-Fisch Handelsgesellschaft mbH
# 13          14                 Formaggi Fortini s.r.l.
# 14          15                         Norske Meierier
# 15          16                       Bigfoot Breweries
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SupplierID    29 non-null     int64
#  1   CompanyName   29 non-null     object
#  2   ContactName   29 non-null     object
#  3   ContactTitle  29 non-null     object
#  4   Address       29 non-null     object
#  5   City          29 non-null     object
#  6   Region        9 non-null      object
#  7   PostalCode    29 non-null     object
#  8   Country       29 non-null     object
#  9   Phone         29 non-null     object
#  10  Fax           13 non-null     object
#  11  HomePage      5 non-null      object
# dtypes: int64(1), object(11)
# memory usage: 2.8+ KB

# %%
# Get max character length of each column from Pandas dataframe
for x in range(len(df.columns)):
    print(f'Column name: {list(df.columns)[x]},\t{df[df.columns[x]].astype(str).str.len().max()}')
# Out:
# Column name: SupplierID,	2
# Column name: CompanyName,	38
# Column name: ContactName,	26
# Column name: ContactTitle,	28
# Column name: Address,	45
# Column name: City,	13
# Column name: Region,	8
# Column name: PostalCode,	8
# Column name: Country,	11
# Column name: Phone,	15
# Column name: Fax,	15
# Column name: HomePage,	94
